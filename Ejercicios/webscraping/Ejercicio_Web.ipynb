# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# %%
headers = { 'User-Agent' : 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:94.0) Gecko/20100101 Firefox/94.0' }
url= "https://es.wikipedia.org/wiki/Leonardo_DiCaprio"
response = requests.get(url, headers = headers)
response
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(response.content, 'html.parser')
#print(soup)

# %%
lista_enlaces = []
for enlace in soup.find_all('a'):
    lista_enlaces.append(enlace.text)
lista_enlaces
# Out:
# ['',
#  'Ir a la navegación',
#  'Ir a la búsqueda',
#  '',
#  'Festival Internacional de Cine de Cannes de 2019',
#  'Los Ángeles',
#  'California',
#  'Estados Unidos',
#  'Estadounidense',
#  'Actor',
#  'productor de cine',
#  'ambientalista',
#  'Ver lista anexa',
#  'leonardodicaprio.com',
#  '',
#  'editar datos en Wikidata',
#  '/diˈkaːprjo/',
#  'Los Ángeles',
#  '11 de noviembre',
#  '1974',
#  '[1]',
#  'actor',
#  'productor de cine',
#  'ambientalista',
#  'estadounidense',
#  'Óscar al mejor actor',
#  'BAFTA al mejor actor',
#  'El renacido',
#  'Globos de Oro al mejor actor de drama',
#  'El aviador',
#  'Globo de Oro al mejor actor de comedia o musical',
#  'El lobo de Wall Street',
#  'Sindicato de Actores',
#  'Oso de Plata',
#  'Premio Chlotrudis',
#  '[2]',
#  'Los problemas crecen',
#  'ciencia ficción',
#  'terror',
#  'Critters 3',
#  "This Boy's Life",
#  '[3]',
#  '¿A quién ama Gilbert Grape?',
#  '[2]',
#  "Marvin's Room",
#  'The Basketball Diaries',
#  'Romeo + Julieta',
#  'James Cameron',
#  'Titanic',
#  'Atrápame si puedes',
#  'Gangs of New York',
#  'El aviador',
#  '[2]',
#  'Diamante de sangre',
#  'The Departed',
#  'Revolutionary Road',
#  'Django Unchained',
#  'El lobo de Wall Street',
#  'El renacido',
#  'Érase una vez en Hollywood',
#  '[3]',
#  'Shutter Island',
#  'Inception',
#  '[4]',
#  'Orphan',
#  '[5]',
#  '1 Biografía y familia',
#  '2 Trayectoria',
#  '2.1 Primeros trabajos como actor',
#  '2.2 1996-2001: éxito mundial',
#  '2.3 2002-2007: Nuevos reconocimientos',
#  '2.4 2008-presente',
#  '3 Vida personal',
#  '3.1 Activismo ambiental y político',
#  '3.2 Fórmula E',
#  '4 Filmografía',
#  '4.1 Como actor',
#  '4.2 Como productor',
#  '5 Premios',
#  '6 Notas y referencias',
#  '7 Enlaces externos',
#  'editar',
#  'Hollywood',
#  'California',
#  '[6]',
#  'Alemania',
#  'cómic underground',
#  '[1]',
#  '[7]',
#  'Nápoles',
#  'Baviera',
#  '[1]',
#  '[8]',
#  '[9]',
#  '[10]',
#  '[11]',
#  'Rusia',
#  '[12]',
#  '[13]',
#  '[14]',
#  '[15]',
#  'Leonardo da Vinci',
#  '[16]',
#  '[17]',
#  '[1]',
#  'editar',
#  'editar',
#  '[18]',
#  'Matchbox',
#  '[18]',
#  'The New Lassie',
#  'Roseanne',
#  'Premio Young Artist al Mejor Actor Joven',
#  '[3]',
#  'ciencia ficción',
#  'terror,',
#  'Critters 3',
#  '[19]',
#  'sitcom',
#  'ABC',
#  'Growing Pains',
#  'Robert De Niro',
#  "This Boy's Life",
#  'Ellen Barkin',
#  '[18]',
#  'discapacidad mental',
#  'Johnny Depp',
#  '¿A quién ama Gilbert Grape?',
#  'Iowa',
#  'Lasse Hallström',
#  '[19]',
#  'dólares',
#  '[20]',
#  'National Board of Review',
#  'Premio Óscar',
#  'Globo de Oro',
#  '[3]',
#  'Janet Maslin',
#  'New York Times',
#  '[21]',
#  'Rápida y mortal',
#  'Sam Raimi',
#  'Gene Hackman',
#  'Sharon Stone',
#  'Russell Crowe',
#  '[22]',
#  '[23]',
#  'Jonathan Rosenbaum',
#  'Chicago Reader',
#  'Sergio Leone',
#  '[24]',
#  'Total Eclipse',
#  'Arthur Rimbaud',
#  'Paul Verlaine',
#  'David Thewlis',
#  'River Phoenix',
#  '[25]',
#  '[26]',
#  'Tobey Maguire',
#  "Don's Plum",
#  '[18]',
#  '[18]',
#  'Festival Internacional de Cine de Berlín',
#  'Time Out New York',
#  "Mike D'Angelo",
#  '[27]',
#  'The Basketball Diaries',
#  'película biográfica',
#  'Jim Carroll',
#  'editar',
#  'Claire Danes',
#  'Baz Luhrmann',
#  'Romeo + Julieta',
#  'William Shakespeare',
#  '[28]',
#  "Marvin's Room",
#  'Robert De Niro',
#  'Meryl Streep',
#  'Diane Keaton',
#  '[29]',
#  '[30]',
#  'Premio Chlotrudis',
#  'Entertainment Weekly',
#  '[30]',
#  '',
#  '',
#  'La playa',
#  'James Cameron',
#  'Titanic',
#  'Kate Winslet',
#  'RMS Titanic',
#  '[31]',
#  'Avatar',
#  '[32]',
#  '[33]',
#  'Globos de Oro',
#  '[3]',
#  '[34]',
#  'cameo',
#  'Woody Allen',
#  'Celebrity',
#  'Luis XIV de Francia',
#  'El hombre de la máscara de hierro',
#  'Randall Wallace',
#  '[35]',
#  '[36]',
#  'Entertainment Weekly',
#  'Owen Gleiberman',
#  '[37]',
#  'Premio Golden Raspberry',
#  '[3]',
#  'La playa',
#  'Alex Garland',
#  'Tilda Swinton',
#  'Virginie Ledoyen',
#  'Golfo de Tailandia',
#  '[38]',
#  '[39]',
#  'Variety',
#  '[40]',
#  'editar',
#  'crimen-comedia',
#  'Atrápame si puedes',
#  'Frank Abagnale Jr.',
#  'Steven Spielberg',
#  'Tom Hanks',
#  'Christopher Walken',
#  '[41]',
#  '[42]',
#  'Roger Ebert',
#  '[43]',
#  '[3]',
#  '',
#  '',
#  'Gangs of New York',
#  'Festival de Cine de Cannes',
#  '',
#  '',
#  'Cameron Diaz',
#  'Martin Scorsese',
#  'Gangs of New York',
#  'Martin Scorsese',
#  'distrito Five Points',
#  'Miramax Films',
#  '[44]',
#  '[44]',
#  '[45]',
#  'Daniel Day-Lewis',
#  '[44]',
#  '[46]',
#  'Howard Hughes',
#  'El aviador',
#  'Michael Mann',
#  'Ali',
#  'The Insider',
#  '[46]',
#  'John Logan',
#  '[47]',
#  '[46]',
#  '[48]',
#  'Globo de Oro a Mejor Actor',
#  '[3]',
#  '2006',
#  'Diamante de sangre',
#  'The Departed',
#  'Edward Zwick',
#  'Jennifer Connelly',
#  'Djimon Hounsou',
#  'guerra civil en Sierra Leona',
#  '[49]',
#  'afrikáner',
#  '[50]',
#  'Boston',
#  '[51]',
#  '[52]',
#  'Premio Satellite al mejor actor de reparto',
#  '[3]',
#  'Premios del Sindicato de Actores',
#  '[3]',
#  'editar',
#  'Red de mentiras',
#  'David Ignatius',
#  'guerra contra el terrorismo',
#  '[53]',
#  'Ridley Scott',
#  'Russell Crowe',
#  'Vince Colosimo',
#  'Three Days of the Condor',
#  '[53]',
#  '[54]',
#  '[55]',
#  '',
#  '',
#  'Kate Winslet',
#  'Revolutionary Road',
#  'Sam Mendes',
#  'Vía revolucionaria',
#  'Richard Yates',
#  '[56]',
#  '[57]',
#  '[58]',
#  '[59]',
#  '[60]',
#  '[3]',
#  '',
#  '',
#  'thriller psicológico',
#  'Shutter Island',
#  'novela homónima',
#  'Dennis Lehane',
#  'Ben Kingsley',
#  'Mark Ruffalo',
#  'Michelle Williams',
#  '[61]',
#  'ciencia ficción',
#  'Inception',
#  'Christopher Nolan',
#  'sueño lúcido',
#  'incubación del sueño',
#  '[62]',
#  '[63]',
#  '[64]',
#  '[65]',
#  '[66]',
#  '[67]',
#  'J. Edgar',
#  'Clint Eastwood',
#  'J. Edgar Hoover',
#  'FBI',
#  '[68]',
#  'Quentin Tarantino',
#  'Django Unchained',
#  '[69]',
#  '[70]',
#  '[71]',
#  'The Great Gatsby',
#  'Baz Luhrmann',
#  'homónima',
#  'F. Scott Fitzgerald',
#  '[72]',
#  'Martin Scorsese',
#  'Jordan Belfort',
#  'The Wolf of Wall Street',
#  'Globo de Oro',
#  '[73]',
#  'El renacido',
#  'Hugh Glass',
#  'Alejandro González Iñárritu',
#  '[74]',
#  '[75]',
#  '[76]',
#  'Óscar',
#  '[77]',
#  'Globo de Oro',
#  'BAFTA',
#  '[78]',
#  '[79]',
#  '[80]',
#  '[79]',
#  '[81]',
#  '[82]',
#  'Stephan Talty',
#  '[83]',
#  '[84]',
#  'Appian Way Productions',
#  '[85]',
#  '[86]',
#  'Theodore Roosevelt',
#  '[87]',
#  '[88]',
#  'Érase una vez en Hollywood',
#  '[89]',
#  '[90]',
#  '[91]',
#  '[91]',
#  '[92]',
#  '[93]',
#  '[94]',
#  '[95]',
#  '[96]',
#  '[97]',
#  '[98]',
#  'El último baile',
#  '[99]',
#  'editar',
#  '',
#  '',
#  '[100]',
#  '[101]',
#  'modelo',
#  'brasileña',
#  'Gisele Bündchen',
#  '[102]',
#  'israelí',
#  'Bar Refaeli',
#  'Shimon Peres',
#  'Hod HaSharon',
#  '[103]',
#  '[104]',
#  'Toni Garrn',
#  '[105]',
#  'Camila Morrone',
#  '[106]',
#  '[107]',
#  'Los Ángeles',
#  'Battery Park City',
#  'Manhattan',
#  '[108]',
#  'Belice',
#  '[109]',
#  '[110]',
#  'Dinah Shore',
#  'Palm Springs',
#  'California',
#  'arte',
#  'escándalo de lavado de dinero',
#  '[111]',
#  '[112]',
#  'agnóstico',
#  '[113]',
#  'editar',
#  'ecologista',
#  'ambientales',
#  'vuelos comerciales',
#  'vehículo híbrido eléctrico',
#  'paneles solares',
#  'Orlando Bloom',
#  'Penélope Cruz',
#  '[114]',
#  '[115]',
#  'calentamiento global',
#  'medio ambiente',
#  '[116]',
#  'GLAAD',
#  'LGBT',
#  '[117]',
#  '[118]',
#  'editar',
#  'Venturi',
#  'Venturi Formula E Team',
#  'Fórmula E',
#  'Federación Internacional del Automóvil',
#  '[119]',
#  'editar',
#  ' Anexo:Filmografía de Leonardo DiCaprio',
#  'editar',
#  'Critters 3',
#  '[120]',
#  'Poison Ivy',
#  "This Boy's Life",
#  'Tobias "Toby" Wolff',
#  'Chicago Film Critics Association por Actor Revelación',
#  '[121]',
#  '¿A quién ama Gilbert Grape?',
#  'Chicago Film Critics Association por Actor Revelación',
#  'Premio Óscar por Mejor Actor de Reparto',
#  'Globo de Oro a Mejor Actor de Reparto',
#  '[122]',
#  'Rápida y mortal',
#  '[123]',
#  'The Basketball Diaries',
#  'Jim Carroll',
#  '[124]',
#  'Total Eclipse',
#  'Arthur Rimbaud',
#  '[125]',
#  'Romeo + Juliet',
#  'Premio Blockbuster Entertainment por Actor Favorito - Romance',
#  'Oso de Plata por Mejor Actor',
#  'Claire Danes',
#  'Claire Danes',
#  '[126]',
#  "Marvin's Room",
#  'Premio del Sindicato de Actores al Mejor Reparto',
#  '[127]',
#  'Titanic',
#  'Jack Dawson',
#  'Premio Blockbuster Entertainment por Actor Favorito - Drama',
#  'Globo de Oro al Mejor Actor - Drama',
#  'Kate Winslet',
#  'Kate Winslet',
#  'Premio del Sindicato de Actores al Mejor Reparto',
#  '[128]',
#  'El hombre de la máscara de hierro',
#  'Luis XIV',
#  'Premio razzie a la peor pareja de actores',
#  '[129]',
#  'Celebrity',
#  'Teen Choice Award',
#  '[130]',
#  'The Grove Family',
#  'Teen Choice Award',
#  'La playa',
#  'Teen Choice Award por Elección de Actor de Película – Drama',
#  'Teen Choice Award por Elección en Química',
#  'Virginie Ledoyen',
#  '[131]',
#  "Don's Plum",
#  '[132]',
#  'Atrápame si puedes',
#  'Frank William Abagnale Jr.',
#  'Teen Choice Awards',
#  'Globo de Oro al mejor actor - Drama',
#  '[133]',
#  'Gangs of New York',
#  'Cameron Diaz',
#  'Teen Choice Awards',
#  'Cameron Diaz',
#  '[134]',
#  'The Aviator',
#  'Howard Hughes',
#  'Globo de Oro al Mejor Actor',
#  'Óscar al Mejor Actor',
#  'BAFTA al Mejor Actor',
#  'Premio del Sindicato de Actores al Mejor Reparto',
#  'Premio del Sindicato de Actores Al Mejor Actor Protagonista',
#  'Teen Choice Awards',
#  '[135]',
#  'Diamante de sangre',
#  'Óscar al Mejor Actor',
#  'The Departed',
#  'Globo de Oro al Mejor Actor',
#  'Premio del Sindicato de Actores al Mejor Actor Protagonista',
#  '[136]',
#  'The Departed',
#  'Premio Cine de los Estados Unidos por Mejor Actor',
#  'BAFTA al Mejor Actor',
#  'Blood Diamond',
#  'Premio Empire por Mejor Actor',
#  'Globo de Oro al Mejor Actor - Drama',
#  "Premios People's Choice",
#  'Matt Damon',
#  'Jack Nicholson',
#  'Premio del Sindicato de Actores al Mejor Reparto',
#  'Premio del Sindicato de Actores al Mejor Actor de Reparto',
#  'Teen Choice Awards por Elección de Actor de Películas - Drama',
#  '[137]',
#  'The 11th Hour',
#  '[138]',
#  'Red de Mentiras',
#  '[139]',
#  'Revolutionary Road',
#  'Premio al Festival Internacional de Cine de Palm Springs por Mejor Interpretación en Unidad',
#  'Globo de Oro al Mejor Actor',
#  '[140]',
#  'Shutter Island',
#  'Inception',
#  'Inception',
#  '[141]',
#  'Hubble 3D',
#  '[142]',
#  'Inception',
#  'Shutter Island',
#  'Shutter Island',
#  '[143]',
#  'J. Edgar',
#  'J. Edgar Hoover',
#  'Globo de Oro al Mejor Actor',
#  'Premio del Sindicato de Actores al Mejor Actor Protagonista',
#  'Broadcast Film Critics Association',
#  '[144]',
#  'Django Unchained',
#  'Globo de Oro al mejor actor de reparto',
#  '[145]',
#  'El gran Gatsby',
#  "People's Choice Awards",
#  'Teen Choice Awards por Elección de Actor de Películas - Drama',
#  '[146]',
#  'El lobo de Wall Street',
#  'Globo de oro al mejor actor comedia o musical',
#  'Óscar al Mejor Actor',
#  'BAFTA al Mejor Actor',
#  '[147]',
#  'El renacido',
#  'Hugh Glass',
#  'Óscar al Mejor Actor',
#  'Globo de Oro al Mejor Actor',
#  'BAFTA al Mejor Actor',
#  "Critics' Choice Award al Mejor Actor",
#  '[148]',
#  'The Audition',
#  '[149]',
#  'Once Upon a Time in Hollywood',
#  '[150]',
#  'Óscar al Mejor Actor',
#  'Globo de Oro al Mejor Actor',
#  'Premio del Sindicato de Actores al Mejor Actor Protagonista',
#  "Premio Critics' Choice Award al Mejor Actor",
#  'BAFTA al Mejor Actor',
#  '[151]',
#  'No miren arriba',
#  'Globo de Oro al Mejor Actor',
#  '[152]',
#  'Killers of the Flower Moon',
#  '[153]',
#  '',
#  '',
#  'John Kerry',
#  'Before the Flood',
#  'editar',
#  'El asesinato de Richard Nixon',
#  '[154]',
#  'El aviador',
#  '[155]',
#  'The 11th Hour',
#  '[156]',
#  '[157]',
#  'La huérfana',
#  '[158]',
#  'Red Riding Hood',
#  'The Ides of March',
#  '[159]',
#  '[160]',
#  'Runner Runner',
#  'The Wolf of Wall Street',
#  '[161]',
#  '[162]',
#  'Live By Night',
#  'Before the Flood',
#  '[163]',
#  '[164]',
#  'Richard Jewell',
#  '[165]',
#  'editar',
#  ' Anexo:Premios y nominaciones de Leonardo DiCaprio',
#  '[166]',
#  '[167]',
#  '66.º Premios Óscar',
#  'mejor actor de reparto',
#  '¿A quién ama Gilbert Grape?',
#  '77.º Premios Óscar',
#  'mejor actor',
#  'El Aviador',
#  '79.º Premios Óscar',
#  'Diamante de sangre',
#  '86.º Premios Óscar',
#  'mejor película',
#  'El lobo de Wall Street',
#  '88.º Premios Óscar',
#  'El renacido',
#  '92.º Premios Óscar',
#  'Érase una vez en Hollywood',
#  'Premios Globo de Oro',
#  'Mejor actor - Drama',
#  'Mejor actor - Comedia o musical',
#  '[168]',
#  'premio BAFTA al mejor actor',
#  '[169]',
#  'editar',
#  'a',
#  'b',
#  'c',
#  'd',
#  'Leonardo DiCaprio: Modern-Day Romeo',
#  '7-15',
#  'ISBN',
#  '0-440-22701-1',
#  'ayuda',
#  'a',
#  'b',
#  'c',
#  '«Leonardo DiCaprio y la larga espera por el Oscar»',
#  'a',
#  'b',
#  'c',
#  'd',
#  'e',
#  'f',
#  'g',
#  'h',
#  'i',
#  'j',
#  'k',
#  '«Awards for Leonardo DiCaprio»',
#  'IMDb',
#  '↑',
#  '«Entertainment News\xa0» SCORSESE LIKENS DiCAPRIO TO DE NIRO»',
#  '↑',
#  '«El ecologista Leonardo DiCaprio»',
#  '↑',
#  'People',
#  '«Leonardo DiCaprio»',
#  '↑',
#  '«Leonardo DiCaprio Biography (1974?-)»',
#  '↑',
#  '«LEONARDO DICAPRIO; Scumsville superstar; HIS PARENTS WERE HIPPIES, AND HE GREW UP IN THE POOREST PART OF TOWN.(Features) – The People (London, England) – HighBeam Research»',
#  'el original',
#  '↑',
#  "«Poverty and family split spurred Leo to pounds 3m a film Titanic stardom; Gran tells of screen idol's battle»",
#  'el original',
#  '↑',
#  "Leonardo DiCaprio - Biography - The premiere of This Boy's life",
#  '↑',
#  "«Leonardo DiCaprio's Grandmother Helene Indenbirken Dies at 93»",
#  'el original',
#  '↑',
#  '«Russians Lift Vodka Glasses to DiCaprio»',
#  '↑',
#  "«Vladimir Putin: Leonardo DiCaprio is a 'real man'.»",
#  '↑',
#  "«Vladimir Putin: Leonardo DiCaprio is a 'real man'.»",
#  '↑',
#  '«Leonardo DiCaprio legend - Hollywood legend - American actor and film producer»',
#  'el original',
#  '↑',
#  '«Leonardo Dicaprio»',
#  'el original',
#  '↑',
#  '«Is Leo now a convert to the idea of marriage?»',
#  'Daily Mail',
#  'a',
#  'b',
#  'c',
#  'd',
#  'e',
#  '«Riding The Wave»',
#  'People',
#  'a',
#  'b',
#  "«The Actor Is Boyishly Handsome, and That's a Liability»",
#  'The New York Times',
#  '↑',
#  "«What's Eating Gilbert Grape (1993)»",
#  '↑',
#  "«Movie Review: What's Eating Gilbert Grape»",
#  'The New York Times',
#  '↑',
#  '↑',
#  '«The Quick and the Dead (1995)»',
#  '↑',
#  '«The Quick and the Dead review»',
#  'Chicago Reader',
#  '↑',
#  '«Fresh Blood»',
#  'The New York Times',
#  '↑',
#  '«Total Eclipse (1995)»',
#  '↑',
#  "«Don's Plum review»",
#  'Time Out New York',
#  '↑',
#  '«Romeo + Juliet (1996)»',
#  '↑',
#  '«Two Wrenching Dramas Find Unexpected New Lives»',
#  'The New York Times',
#  'a',
#  'b',
#  "«Marvin's Room (1996)»",
#  'Entertainment Weekly',
#  '↑',
#  '«Titanic. Man Overboard!»',
#  'Entertainment Weekly',
#  '↑',
#  '«Worldwide Grosses»',
#  '↑',
#  "«Leonardo DiCaprio's Magnificent Obsessive»",
#  'The Telegraph',
#  '↑',
#  "«What's Eating Leonardo DiCaprio»",
#  'Time',
#  '↑',
#  '«The Man in the Iron Mask»',
#  'Rotten Tomatoes',
#  '↑',
#  '«The Man in the Iron Mask (1998)»',
#  '↑',
#  '«The Man in the Iron Mask (1998)»',
#  'Entertainment Weekly',
#  '↑',
#  '«The Beach (2000)»',
#  '↑',
#  '«The Beach (2000)»',
#  'Rotten Tomatoes',
#  '↑',
#  '«The Beach Review»',
#  'Variety',
#  'el original',
#  '↑',
#  '«Daily News – Catch Me If You Can.»',
#  '↑',
#  '«Catch Me If You Can (2002)»',
#  '↑',
#  '«Catch Me If You Can (2002) Review»',
#  'Chicago Sun-Times',
#  'a',
#  'b',
#  'c',
#  "«Scorsese's Gang Of Acting Heavyweights»",
#  '↑',
#  '«Gangs of New York (2002)»',
#  'a',
#  'b',
#  'c',
#  '«How Do You Like Your Leonardo DiCaprio? Butch Or Boyish? The Choice Is Yours»',
#  'The Observer',
#  '↑',
#  '«Leonardo DiCaprio Gets Obsessive About The Aviator.»',
#  '↑',
#  '«The Aviator (2004)»',
#  'Rotten Tomatoes',
#  '↑',
#  '«Blood Diamond»',
#  'Metacritic',
#  '↑',
#  '«Leonardo DiCaprio Interview for Blood Diamond»',
#  'el original',
#  '↑',
#  '«The Departed (2006)»',
#  'Rotten Tomatoes',
#  '↑',
#  '«The Departed (2006)»',
#  'a',
#  'b',
#  "«Leonardo DiCaprio And Russell Crowe Will Be A Good 'Fit' In CIA Flick, Ridley Scott Hopes»",
#  '↑',
#  '«Body of Lies (2008)»',
#  'Rotten Tomatoes',
#  '↑',
#  '«Body Of Lies(2008)»',
#  '↑',
#  'DiCaprio Reveals Joys Of Fighting With Winslet',
#  '↑',
#  '«Kate! Leo! Gloom! Doom! Can It Work?»',
#  'The New York Times',
#  '↑',
#  '«In Revolutionary Road, Leo DiCaprio Just An Ordinary Guy»',
#  '↑',
#  '«Interview: Kate Winslet on Revolutionary Road.»',
#  'el original',
#  '↑',
#  '«Revolutionary Road (2008)»',
#  'Rotten Tomatoes',
#  '↑',
#  '«Shutter Island Lights Up»',
#  'Box Office Mojo',
#  '↑',
#  "«Inside 'Inception': Could Christopher Nolan's Dream World Exist in Real Life? Dream Experts Say 'Inception's' Conception of the Subconscious Isn't Far From Science»",
#  'ABC News',
#  'The Walt Disney Company',
#  '↑',
#  '«Inception Synopsis»',
#  '↑',
#  '«Updated ‘Inception’ Synopsis Reveals More»',
#  '↑',
#  '«Christopher Nolan and Emma Thomas Interview»',
#  '↑',
#  '↑',
#  '«Inception (2010)»',
#  'Box Office Mojo',
#  'Internet Movie Database',
#  '↑',
#  "«After 'Inception,' What's Next For Leonardo DiCaprio?»",
#  'MTV News',
#  '↑',
#  "«Leonardo DiCaprio In Talks for Villainous Role in Quentin Tarantino's Django Unchained»",
#  'el original',
#  '↑',
#  '«Django Unchained»',
#  '↑',
#  '«Django Unchained»',
#  '↑',
#  '«Baz Luhrmann Tells Deadline: Carey Mulligan Is My Daisy Buchanan»',
#  '↑',
#  '«DiCaprio gana el Globo de Oro»',
#  'el original',
#  '↑',
#  "«Review: 'The Revenant' A Mesmerizing, Brilliant Film»",
#  '↑',
#  '«The Revenant: first reactions to DiCaprio thriller suggest Oscar potential»',
#  '↑',
#  "«Leonardo DiCaprio's 'The Revenant' is a brutal test for awards voters»",
#  '↑',
#  '«As it happened: Leonardo DiCaprio wins Best Actor, Spotlight is Best Picture at Oscars 2016»',
#  'ISSN',
#  '0971-751X',
#  '↑',
#  '«Golden Globes 2016: Complete list of winners and nominees»',
#  'a',
#  'b',
#  '«Leonardo DiCaprio, Alejandro G. Inarritu Open Up About ‘The Revenant’s’ Brutal Shoot»',
#  '↑',
#  "«Leonardo DiCaprio on Fighting a Bear in 'The Revenant' and Film vs. TV»",
#  '↑',
#  '«The Revenant»',
#  '↑',
#  '«Paramount Acquires ‘The Black Hand’ For Leonardo DiCaprio To Star For The Gotham Group And Appian Way»',
#  '↑',
#  '«Leonardo DiCaprio to star in film about the precursor to the American Mafia»',
#  '↑',
#  '«Leonardo DiCaprio to star in and produce The Black Hand»',
#  '↑',
#  '«Update: Paramount Wins Leonardo Battle: Lands Walter Isaacson Da Vinci Book For DiCaprio»',
#  '↑',
#  '«Paramount Wins Bidding War for Leonardo da Vinci Biopic Starring Leonardo DiCaprio»',
#  '↑',
#  '«Leonardo DiCaprio to Play Theodore Roosevelt in Martin Scorsese-Directed Biopic»',
#  '↑',
#  '«Leonardo DiCaprio brings his father George to Ice on Fire premiere»',
#  '↑',
#  '«Celebrity Salaries Revealed: Leonardo DiCaprio, Margot Robbie & More – Variety»',
#  '↑',
#  "«Quentin Tarantino says Brad Pitt-Leo DiCaprio have 'most exciting star dynamic' since Robert Redford-Paul Newman - Entertainment News , Firstpost»",
#  'a',
#  'b',
#  "«Three Kings: Quentin, Brad, and Leo Take You Inside 'Once Upon a Time...In Hollywood'»",
#  '↑',
#  'Once Upon a Time In Hollywood (2019)',
#  '↑',
#  "«Leonardo DiCaprio gives career best in 'Once Upon a Time in Hollywood' - Business Insider»",
#  '↑',
#  '«Does Once Upon a Time in Hollywood succeed?»',
#  '↑',
#  '«Oscar Nominations 2020: The Complete List»',
#  '↑',
#  '«2020 Golden Globes Nominations: Full List of Nominees – Variety»',
#  '↑',
#  '«Bafta Film Awards 2020: The winners in full»',
#  '↑',
#  '«Once Upon a Time... In Hollywood»',
#  '↑',
#  '«Leonardo DiCaprio Met Michael Jordan in The Last Dance Finale»',
#  '↑',
#  '«Leonardo DiCaprio - Movies - The New York Times»',
#  '↑',
#  '«Leonardo DiCaprio: The enigmatic actor»',
#  '↑',
#  '«Gisele Bündchen on why she broke up with Leonardo DiCaprio»',
#  '↑',
#  "«Leo and Bar. What's going on?»",
#  '↑',
#  '«Israeli Leader Asks Leonardo DiCaprio for Help»',
#  '↑',
#  '«Leonardo DiCaprio, model Toni Garrn reportedly split»',
#  '↑',
#  '«Leonardo DiCaprio y Camila Morrone se dejaron ver muy juntos en Coachella - E! Online Latino»',
#  '↑',
#  '«¡Hace 15 años que no lo hacía!: el gran gesto de Leo DiCaprio con Camila Morrone en los Oscars»',
#  '↑',
#  '«Leonardo DiCaprio»',
#  '↑',
#  '«Leonardo DiCaprio Builds an Eco-Resort (Published 2015)»',
#  'ISSN',
#  '0362-4331',
#  '↑',
#  "«The sea-cooled eco-resort that's nearly mosquito-free»",
#  '↑',
#  '«Leonardo DiCaprio turns over Marlon Brando Oscar, other gifts allegedly bought with 1MDB funds»',
#  '↑',
#  'Celebrity Biographies - The Amazing Life Of Leonardo DiCaprio - Famous Actors',
#  '↑',
#  '«Leonardo DiCaprio faces his demons»',
#  '↑',
#  '«Leonardo DiCaprio Builds an Eco-Resort (Published 2015)»',
#  'ISSN',
#  '0362-4331',
#  '↑',
#  '«Leonardo DiCaprio gets the keys to a $100,000 car — a hybrid»',
#  '↑',
#  '«Leonardo DiCaprio named as United Nations climate change envoy»',
#  '↑',
#  '«Leonardo DiCaprio Donates $61,000 to Support Gay Rights at Annual GLAAD Media Awards»',
#  '↑',
#  "«Watch Leonardo DiCaprio's 2016 Oscar Acceptance Speech for Best Actor»",
#  '↑',
#  '«Leo and Venturi Automobiles team up»',
#  '↑',
#  '«Critters 3 – review | cast and crew, movie star rating and where to watch film on TV and online»',
#  '↑',
#  'Leonardo DiCaprio\xa0: the biography',
#  'ISBN',
#  '978-1-85782-672-2',
#  'OCLC',
#  '775030390',
#  '↑',
#  '«Movie Reviews»',
#  'ISSN',
#  '0362-4331',
#  '↑',
#  '«The Quick And The Dead movie review (1995) | Roger Ebert»',
#  'https://www.rogerebert.com/',
#  '↑',
#  '«Movie Reviews»',
#  'ISSN',
#  '0362-4331',
#  '↑',
#  "«MOVIE REVIEW\xa0: 'Eclipse' a Grim Tale of Licentious Poets»",
#  '↑',
#  '«William Shakespeare’s Romeo & Juliet»',
#  '↑',
#  '«Marvin’s Room»',
#  '↑',
#  '«Titanic movie review & film summary (1997) | Roger Ebert»',
#  'https://www.rogerebert.com/',
#  '↑',
#  '«Movie Reviews»',
#  'ISSN',
#  '0362-4331',
#  '↑',
#  '«Celebrity movie review & film summary (1998) | Roger Ebert»',
#  'https://www.rogerebert.com/',
#  ...]
