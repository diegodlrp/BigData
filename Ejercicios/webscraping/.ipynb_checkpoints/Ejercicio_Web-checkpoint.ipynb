# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# %%
headers = { 'User-Agent' : 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:94.0) Gecko/20100101 Firefox/94.0' }
url= "https://es.wikipedia.org/wiki/Leonardo_DiCaprio"
response = requests.get(url, headers = headers)
response
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(response.content, 'html.parser')
#print(soup)

# %%
lista_enlaces = []
for enlace in soup.find_all('a'):
    lista_enlaces.append(enlace.text)
lista_enlaces
# Out:
# ['',
#  'Ir a la navegación',
#  'Ir a la búsqueda',
#  '',
#  'Festival Internacional de Cine de Cannes de 2019',
#  'Los Ángeles',
#  'California',
#  'Estados Unidos',
#  'Estadounidense',
#  'Actor',
#  'productor de cine',
#  'ambientalista',
#  'Ver lista anexa',
#  'leonardodicaprio.com',
#  '',
#  'editar datos en Wikidata',
#  '/diˈkaːprjo/',
#  'Los Ángeles',
#  '11 de noviembre',
#  '1974',
#  '[1]',
#  'actor',
#  'productor de cine',
#  'ambientalista',
#  'estadounidense',
#  'Óscar al mejor actor',
#  'BAFTA al mejor actor',
#  'El renacido',
#  'Globos de Oro al mejor actor de drama',
#  'El aviador',
#  'Globo de Oro al mejor actor de comedia o musical',
#  'El lobo de Wall Street',
#  'Sindicato de Actores',
#  'Oso de Plata',
#  'Premio Chlotrudis',
#  '[2]',
#  'Los problemas crecen',
#  'ciencia ficción',
#  'terror',
#  'Critters 3',
#  "This Boy's Life",
#  '[3]',
#  '¿A quién ama Gilbert Grape?',
#  '[2]',
#  "Marvin's Room",
#  'The Basketball Diaries',
# ...

# %%
#table wikitable
tables = soup.find(class_='wikitable')
tableTr = tables.find_all("tr")
fecha = []
titulo = []
notas = []
for i in range(0,len(tableTr),1):
    
    th = tableTr[i].find_all(['td','th'])
    if(i != 4 and i !=6 and i != 7 and i != 9 and i != 12 and i !=13 and i != 17 and i != 20 and i != 23 and i != 26 and i != 30 and i != 32):
        fecha.append(th[0].text.strip())
        titulo.append(th[1].text.strip())
        notas.append(th[3].text.strip())
    else:
        fecha.append("")
        titulo.append(th[0].text.strip())
        notas.append(th[2].text.strip())
    
df = pd.DataFrame({"fecha":fecha,"titulo":titulo,"notas":notas})
df
# Out:
#    fecha                             titulo  \
# 0    Año                             Título
# 1   1991                         Critters 3
# 2   1992                         Poison Ivy
# 3   1993                    This Boy's Life
# 4               ¿A quién ama Gilbert Grape?
# 5   1995                    Rápida y mortal
# 6                    The Basketball Diaries
# 7                             Total Eclipse
# 8   1996                     Romeo + Juliet
# 9                             Marvin's Room
# 10  1997                            Titanic
# 11  1998  El hombre de la máscara de hierro
# 12                                Celebrity
# 13                         The Grove Family
# 14  2000                           La playa
# 15  2001                         Don's Plum
# 16  2002                 Atrápame si puedes
# 17                        Gangs of New York
# 18  2004                        The Aviator
# 19  2006                 Diamante de sangre
# ...

# %%
listapremios = soup.find_all("ul")
listapremios[5]
a_listapremios = listapremios[5].find_all("a")
for i in range(0,len(a_listapremios),1):
    print(a_listapremios[i].text.strip())
# Out:
# 66.º Premios Óscar
# mejor actor de reparto
# ¿A quién ama Gilbert Grape?
# 77.º Premios Óscar
# mejor actor
# El Aviador
# 79.º Premios Óscar
# Diamante de sangre
# 86.º Premios Óscar
# mejor película
# El lobo de Wall Street
# 88.º Premios Óscar
# El renacido

# %%
img = soup.find("img")
print(img["src"])
print(img["alt"])
print(img["srcset"])

div = soup.find("div")
print(div["id"])
print(div["class"])
# Out:
# //upload.wikimedia.org/wikipedia/commons/thumb/4/46/Leonardo_Dicaprio_Cannes_2019.jpg/220px-Leonardo_Dicaprio_Cannes_2019.jpg
# Leonardo Dicaprio Cannes 2019.jpg
# //upload.wikimedia.org/wikipedia/commons/thumb/4/46/Leonardo_Dicaprio_Cannes_2019.jpg/330px-Leonardo_Dicaprio_Cannes_2019.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/4/46/Leonardo_Dicaprio_Cannes_2019.jpg/440px-Leonardo_Dicaprio_Cannes_2019.jpg 2x
# mw-page-base
# <div class="noprint" id="mw-page-base"></div>
